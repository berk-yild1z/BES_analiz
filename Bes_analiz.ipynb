# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.ticker as mtick
import seaborn as sns
from linearmodels.panel import PanelOLS

# %%
pd.set_option('display.max_columns', None)

# %%
net_giriş_çıkış=pd.read_excel("Data.xlsx",sheet_name="Sisteme Giriş Çıkış")
net_giriş_çıkış["Tarihler"]=pd.to_datetime(net_giriş_çıkış["Tarihler"],format="%Y%m")
net_giriş_çıkış.set_index("Tarihler",inplace=True)
net_giriş_çıkış.describe()
# Out:
#                Giriş       Sonlanma            Net
# count     248.000000     248.000000     248.000000
# mean    98177.173387   51956.245968   46220.927419
# std     52874.912061   36358.364478   37210.179402
# min       382.000000       0.000000  -50046.000000
# 25%     50590.500000   20950.500000   23538.250000
# 50%     95360.000000   44088.000000   35522.000000
# 75%    137134.000000   85919.250000   70312.500000
# max    222357.000000  144590.000000  152045.000000

# %%
fig, ax = plt.subplots()
plt.style.use('fivethirtyeight')  
plt.xlabel("Yıllar")
plt.ylabel("Sisteme Giriş Çıkış Sayısı")
plt.plot(net_giriş_çıkış.index,net_giriş_çıkış["Net"],color="red",linewidth=2, marker="x")
plt.legend(["Net Giriş/Çıkış"])
plt.show()

# %%
katilimci_sertifika=pd.read_excel("Data.xlsx",sheet_name="Katılımcı ve Sertifika Sayısı")
katilimci_sertifika["Date"]=pd.to_datetime(katilimci_sertifika["Date"],format="%d%m%Y")
katilimci_sertifika.set_index("Date",inplace=True)

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
import matplotlib.ticker as mtick
plt.style.use("seaborn-v0_8")
fig, ax = plt.subplots()
plt.xlabel("Yıllar")
plt.ylabel("Katılımcı Ve Sertifika Sayısı")
plt.plot(katilimci_sertifika.index, katilimci_sertifika["Total Number of Participants"], color="red", linewidth=2, marker="o", label="Katılımcı Sayısı")
plt.plot(katilimci_sertifika.index, katilimci_sertifika["Total Number of Contracts and Certificates"], color="blue", linewidth=2, marker="o", label="Sertifika Sayısı")
plt.ylim(6700000, 10970000)
ax.get_yaxis().set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))
plt.legend()
plt.show()

# %%
fon_tercih=pd.read_excel("Data.xlsx",sheet_name="Fon Grubu Tercihi")
fon_tercih["Tarih"]=pd.to_datetime(fon_tercih["Tarih"],format="%Y%m")
fon_tercih.set_index("Tarih",inplace=True)
fon_tercih
# Out:
#             Kıymetli Maden  Standart Fon  Hisse Senedi       Endeks  \
# Tarih
# 2019-12-01     28897969321    8945003257    5156615489    564144970
# 2020-03-01     28107052304    8676171040    4592097944    457856409
# 2020-06-01     30727874222    9542948741    6014621714    618258431
# 2020-09-01     35767649774    9048680697    5730791292    638637475
# 2020-12-01     36090461749    9462766193    7698893287    940158301
# 2021-03-01     36105862939    9136781953    7417239195    999710181
# 2021-06-01     40127916695    9367960673    7284694551    917300981
# 2021-09-01     40611860605    9642745307    8126580426   1020585878
# 2021-12-01     63862433937   10887420606    9874482422   1539839326
# 2022-03-01     78672216645   11528122530   10740251739   2032879966
# 2022-06-01     86377498586   11852271902   11717141883   2989038523
# 2022-09-01     93807064174   13925457395   11807260086   3428799047
# 2022-12-01    107310283432   15068621668   11971393385   6287206070
# ...

# %%
fig, ax = plt.subplots(1, 5, figsize=(20, 5))  # Boyutu daha uygun hale getirdim

for i, column in enumerate(fon_tercih.columns):
    ax[i].plot(fon_tercih.index, fon_tercih[column], marker='o', label=column)
    ax[i].set_xlabel('Tarih')
    ax[i].set_ylabel('Değer')
    ax[i].set_title(f'{column}')
    ax[i].get_yaxis().set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))
    ax[i].legend()
    ax[i].grid(True)
    ax[i].tick_params(axis='x', rotation=45)
fig.suptitle('Yatırım Terchilerinin Zaman İçinde Değişimi', fontsize=16)
plt.tight_layout()  # Tüm alt grafikler için yerleşimi ayarla
plt.show()

# %%
comeback_rate=pd.read_excel("Data.xlsx",sheet_name="Geri Dönme Oranı")
comeback_rate["Date"]=pd.to_datetime(comeback_rate["Date"],format="%Y")
comeback_rate.set_index("Date",inplace=True)
comeback_rate
# Out:
#             Comeback Rate
# Date
# 2006-01-01            1.9
# 2007-01-01            3.1
# 2008-01-01            4.5
# 2009-01-01            6.4
# 2010-01-01            6.8
# 2011-01-01            6.8
# 2012-01-01            7.5
# 2013-01-01            7.6
# 2014-01-01            7.3
# 2015-01-01            8.1
# 2016-01-01            9.4
# 2017-01-01           11.4
# 2018-01-01           13.1
# 2019-01-01           16.1
# 2020-01-01           16.8
# 2021-01-01           14.7
# 2022-01-01           14.0
# 2023-01-01           13.4

# %%
plt.style.use("tableau-colorblind10")
fig, ax = plt.subplots()

plt.plot(comeback_rate.index,comeback_rate["Comeback Rate"],marker='o', label="Geri Dönme Oranı")
plt.xlabel('Tarih')
plt.ylabel('Geri Dönme Oranı')
plt.title("Geri Dönme Oranı")
plt.legend()
plt.show()

# %%
model=pd.read_excel("Data.xlsx",sheet_name="Model")
model.drop(columns=["Participants", "Population", "High School", "University", "Master", "Doctorate", "Education", "25-29", "30-34", "35-39", "40-44", "45-49", "50-54", "55-59", "60-64", "Age","State Province"], inplace=True)
model
# Out:
#      Year State Name  Participants/Population  GDP Per Capita  House Sales  \
# 0    2016      Adana                 0.079828           24086        27723
# 1    2017      Adana                 0.083279           27623        31351
# 2    2018      Adana                 0.081442           31735        30638
# 3    2019      Adana                 0.079725           36812        29574
# 4    2020      Adana                 0.079309           44479        33326
# ..    ...        ...                      ...             ...          ...
# 562  2018      Düzce                 0.063750           37484         8160
# 563  2019      Düzce                 0.064157           43682         7218
# 564  2020      Düzce                 0.064628           52340         7852
# 565  2021      Düzce                 0.066341           76322         7836
# 566  2022      Düzce                 0.075030          148095         8840
#
#      Education/Age
# 0         0.560839
# 1         0.566493
# ...

# %%
year_index_int = model['Year'].astype(int)
model.set_index(['State Name', year_index_int], inplace=True)

# %%
model.index.names = ['Şehir Adı', 'Yıl']
model.drop(columns="Year",inplace=True)
model
# Out:
#                 Participants/Population  GDP Per Capita  House Sales  \
# Şehir Adı Yıl
# Adana     2016                 0.079828           24086        27723
#           2017                 0.083279           27623        31351
#           2018                 0.081442           31735        30638
#           2019                 0.079725           36812        29574
#           2020                 0.079309           44479        33326
# ...                                 ...             ...          ...
#   Düzce   2018                 0.063750           37484         8160
#           2019                 0.064157           43682         7218
#           2020                 0.064628           52340         7852
#           2021                 0.066341           76322         7836
#           2022                 0.075030          148095         8840
#
#                 Education/Age
# Şehir Adı Yıl
# Adana     2016       0.560839
#           2017       0.566493
# ...

# %%
model.rename(columns={"Participants/Population":"Katılımcı_Nüfus_Oranı","GDP Per Capita": "Kişi_Başına_Düşen_GSYH","House Sales":"Konut_Satışı","Education/Age":"Eğitim_Yaş_Oranı"},inplace=True)

# %%
corr_matrix = model[['Katılımcı_Nüfus_Oranı', 'Kişi_Başına_Düşen_GSYH', 'Konut_Satışı', 'Eğitim_Yaş_Oranı']].corr()
plt.figure(figsize=(10, 7))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Korelasyon Matrisi')
plt.show()

# %%
model_1 = PanelOLS.from_formula('Katılımcı_Nüfus_Oranı ~ Kişi_Başına_Düşen_GSYH + Konut_Satışı + Eğitim_Yaş_Oranı + EntityEffects',model)
results = model_1.fit()
print(results.summary)
# Out:
#                             PanelOLS Estimation Summary
# ...
# Dep. Variable:     Katılımcı_Nüfus_Oranı   R-squared:                        0.5260
# Estimator:                      PanelOLS   R-squared (Between):              0.1996
# No. Observations:                    567   R-squared (Within):               0.5260
# Date:                   Thu, Aug 29 2024   R-squared (Overall):              0.2008
# Time:                           16:02:53   Log-likelihood                    2506.9
# Cov. Estimator:               Unadjusted
#                                            F-statistic:                      178.64
# Entities:                             81   P-value                           0.0000
# Avg Obs:                          7.0000   Distribution:                   F(3,483)
# Min Obs:                          7.0000
# Max Obs:                          7.0000   F-statistic (robust):             178.64
# ...
